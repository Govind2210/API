# %%
#8265bd1679663a7ea12ac168da84d2e8 key TMBD

# %%
import requests
import pandas as pd

# %%
response = requests.get('https://api.themoviedb.org/3/movie/popular?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1').json()

# %%
df

# %%
response
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/fOy2Jurz9k6RnJnMUMRDAgBwru2.jpg',
#    'genre_ids': [16, 10751, 35, 14],
#    'id': 508947,
#    'original_language': 'en',
#    'original_title': 'Turning Red',
#    'overview': 'Thirteen-year-old Mei is experiencing the awkwardness of being a teenager with a twist – when she gets too excited, she transforms into a giant red panda.',
#    'popularity': 6038.256,
#    'poster_path': '/qsdjk9oAKSQMWs0Vt5Pyfh6O4GZ.jpg',
#    'release_date': '2022-03-01',
#    'title': 'Turning Red',
#    'video': False,
#    'vote_average': 7.5,
#    'vote_count': 1242},
#   {'adult': False,
#    'backdrop_path': '/iQFcwSGbZXMkeyKrxbPnwnRo5fl.jpg',
#    'genre_ids': [28, 12, 878],
#    'id': 634649,
#    'original_language': 'en',
#    'original_title': 'Spider-Man: No Way Home',
# ...

# %%
popularity = []
vote_count = []
original_language = []
title = []
overview = []
release_date = []
vote_average = []

for i in response['results']:
    
    
    title.append(i['title'])
    overview.append(i['overview'])
    release_date.append(i['release_date'])
    popularity.append(i['popularity'])
    original_language.append(i['original_language'])
    vote_count.append(i['vote_count'])
    vote_average.append(i['vote_average'])
    
d = {'title':title , 'overview':overview , 'release_date':release_date , 'popularity':popularity , 'original_language':original_language,'vote_count':vote_count , 'vote_average' :vote_average}
    
df = pd.DataFrame(d)

# %%
df
# Out:
#                                       title  \
# 0                               Turning Red
# 1                   Spider-Man: No Way Home
# 2                          The Adam Project
# 3                                   Encanto
# 4                                Black Crab
# 5                                Blacklight
# 6                                The Batman
# 7                          Pil's Adventures
# 8                           Jackass Forever
# 9                           The Grandmother
# 10                                  No Exit
# 11                                     Gold
# 12                               Red Notice
# 13                                 Restless
# 14                           The King's Man
# 15        Hotel Transylvania: Transformania
# 16                               Deep Water
# 17  My Hero Academia: World Heroes' Mission
# 18                     Sonic the Hedgehog 2
# 19                                     Kimi
#
# ...

# %%
final = pd.DataFrame()


for j in range (1,20):
    
    
    response = requests.get('https://api.themoviedb.org/3/movie/popular?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}.format{j}').json()
    
    
    popularity = []
    vote_count = []
    original_language = []
    title = []
    overview = []
    release_date = []
    vote_average = []

    for i in response['results']:


        title.append(i['title'])
        overview.append(i['overview'])
        release_date.append(i['release_date'])
        popularity.append(i['popularity'])
        original_language.append(i['original_language'])
        vote_count.append(i['vote_count'])
        vote_average.append(i['vote_average'])

    d = {'title':title , 'overview':overview , 'release_date':release_date , 'popularity':popularity , 'original_language':original_language,'vote_count':vote_count , 'vote_average' :vote_average}

    df = pd.DataFrame(d)

    final = final.append(df , ignore_index = True)

# %%
final
# Out:
#                                        title  \
# 0                                Turning Red
# 1                    Spider-Man: No Way Home
# 2                                 Black Crab
# 3                           The Adam Project
# 4                                    Encanto
# ..                                       ...
# 375        Hotel Transylvania: Transformania
# 376                               Deep Water
# 377  My Hero Academia: World Heroes' Mission
# 378                     Sonic the Hedgehog 2
# 379                                     Kimi
#
#                                               overview release_date  \
# 0    Thirteen-year-old Mei is experiencing the awkw...   2022-03-01
# 1    Peter Parker is unmasked and no longer able to...   2021-12-15
# 2    To end an apocalyptic war and save her daughte...   2022-03-18
# 3    After accidentally crash-landing in 2022, time...   2022-03-11
# 4    The tale of an extraordinary family, the Madri...   2021-11-24
# ...

# %%
final.to_csv('movie_data_by_me.csv')
